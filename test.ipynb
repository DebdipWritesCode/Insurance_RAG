# %%
import asyncio
from asyncio import Semaphore
import pdfplumber
import tempfile
import httpx
import time

MAX_CONCURRENT_TASKS = 30
BATCH_SIZE = 20

async def download_pdf(url: str) -> str:
    print("📥 Starting PDF download...")
    start_time = time.perf_counter()
    
    async with httpx.AsyncClient() as client:
        response = await client.get(url)
        duration = time.perf_counter() - start_time
        print(f"📶 HTTP Status: {response.status_code} (Download took {duration:.2f} seconds)")
        response.raise_for_status()
        
        with tempfile.NamedTemporaryFile(delete=False, suffix='.pdf') as temp_file:
            temp_file.write(response.content)
            print(f"✅ PDF successfully downloaded and saved to: {temp_file.name}")
            return temp_file.name

async def extract_text_from_pdf(pdf_path: str) -> list[str]:
    print(f"📂 Opening PDF for extraction: {pdf_path}")
    semaphore = Semaphore(MAX_CONCURRENT_TASKS)

    with pdfplumber.open(pdf_path) as pdf:
        pages = pdf.pages
        total_pages = len(pages)
        print(f"📄 Total pages in PDF: {total_pages}")

        async def process_page_batch(start_idx: int, end_idx: int):
            print(f"🧩 Processing batch: pages {start_idx + 1} to {end_idx}")
            async with semaphore:
                def read_batch():
                    batch_text = ""
                    for i in range(start_idx, end_idx):
                        try:
                            print(f"🔍 Extracting text from page {i+1}...")
                            page = pages[i]
                            text = page.extract_text()
                            if text:
                                print(f"✅ Text found on page {i+1} ({len(text)} characters)")
                                batch_text += text + "\n"
                            else:
                                print(f"⚠️ No text found on page {i+1}")
                        except Exception as e:
                            print(f"❌ Error processing page {i+1}: {e}")
                    return batch_text
                return await asyncio.to_thread(read_batch)

        tasks = []
        for i in range(0, total_pages, BATCH_SIZE):
            print(f"📦 Queuing batch from page {i+1} to {min(i + BATCH_SIZE, total_pages)}")
            tasks.append(process_page_batch(i, min(i + BATCH_SIZE, total_pages)))

        print("🚀 Launching all batch tasks...")
        batch_texts = await asyncio.gather(*tasks)
        print("✅ All batch tasks completed.")

        full_text = "\n".join(batch_texts)
        print(f"📚 Total extracted text length: {len(full_text)} characters")

    # Save full text to file
    with open("extracted_text.txt", "w", encoding="utf-8") as f:
        f.write(full_text)
    print("💾 Extracted text saved to 'extracted_text.txt'")

    # Split into chunks
    chunked = [chunk.strip() for chunk in full_text.split("\n\n") if chunk.strip()]
    print(f"📄 Extracted {len(chunked)} chunks from PDF using pdfplumber")
    if chunked:
        print(f"🔍 First chunk preview (100 chars): {repr(chunked[0][:100])}")
    else:
        print("❗ No chunks were extracted.")

    return chunked

# Run the test
pdf_url = "https://hackrx.blob.core.windows.net/assets/principia_newton.pdf?sv=2023-01-03&st=2025-07-28T07%3A20%3A32Z&se=2026-07-29T07%3A20%3A00Z&sr=b&sp=r&sig=V5I1QYyigoxeUMbnUKsdEaST99F5%2FDfo7wpKg9XXF5w%3D"

print("🧪 Starting test...")

chunks = await extract_text_from_pdf(await download_pdf(pdf_url))

print("🧾 Previewing extracted chunks:")
for i, chunk in enumerate(chunks[:3]):
    print(f"\n--- Chunk {i+1} (length: {len(chunk)} chars) ---\n{chunk[:300]}")

print("✅ Test complete.")
# Out:
# 🧪 Starting test...
# 📥 Starting PDF download...
# 📶 HTTP Status: 200 (Download took 82.92 seconds)
# ✅ PDF successfully downloaded and saved to: C:\Users\debdi\AppData\Local\Temp\tmpyem5ypw1.pdf
# 📂 Opening PDF for extraction: C:\Users\debdi\AppData\Local\Temp\tmpyem5ypw1.pdf
# 📄 Total pages in PDF: 594
# 📦 Queuing batch from page 1 to 20
# 📦 Queuing batch from page 21 to 40
# 📦 Queuing batch from page 41 to 60
# 📦 Queuing batch from page 61 to 80
# 📦 Queuing batch from page 81 to 100
# 📦 Queuing batch from page 101 to 120
# 📦 Queuing batch from page 121 to 140
# 📦 Queuing batch from page 141 to 160
# 📦 Queuing batch from page 161 to 180
# 📦 Queuing batch from page 181 to 200
# 📦 Queuing batch from page 201 to 220
# 📦 Queuing batch from page 221 to 240
# 📦 Queuing batch from page 241 to 260
# 📦 Queuing batch from page 261 to 280
# 📦 Queuing batch from page 281 to 300
# 📦 Queuing batch from page 301 to 320
# 📦 Queuing batch from page 321 to 340
# 📦 Queuing batch from page 341 to 360
# 📦 Queuing batch from page 361 to 380
# 📦 Queuing batch from page 381 to 400
# 📦 Queuing batch from page 401 to 420
# 📦 Queuing batch from page 421 to 440
# 📦 Queuing batch from page 441 to 460
# 📦 Queuing batch from page 461 to 480
# 📦 Queuing batch from page 481 to 500
# 📦 Queuing batch from page 501 to 520
# 📦 Queuing batch from page 521 to 540
# 📦 Queuing batch from page 541 to 560
# 📦 Queuing batch from page 561 to 580
# 📦 Queuing batch from page 581 to 594
# 🚀 Launching all batch tasks...
# 🧩 Processing batch: pages 1 to 20
# 🧩 Processing batch: pages 21 to 40
# 🧩 Processing batch: pages 41 to 60
# 🧩 Processing batch: pages 61 to 80
# 🧩 Processing batch: pages 81 to 100
# 🧩 Processing batch: pages 101 to 120
# 🧩 Processing batch: pages 121 to 140
# 🧩 Processing batch: pages 141 to 160
# 🧩 Processing batch: pages 161 to 180
# 🧩 Processing batch: pages 181 to 200
# 🧩 Processing batch: pages 201 to 220
# 🧩 Processing batch: pages 221 to 240
# 🧩 Processing batch: pages 241 to 260
# 🧩 Processing batch: pages 261 to 280
# 🧩 Processing batch: pages 281 to 300
# 🧩 Processing batch: pages 301 to 320
# 🧩 Processing batch: pages 321 to 340
# 🧩 Processing batch: pages 341 to 360
# 🧩 Processing batch: pages 361 to 380
# 🧩 Processing batch: pages 381 to 400
# 🧩 Processing batch: pages 401 to 420
# 🧩 Processing batch: pages 421 to 440
# 🧩 Processing batch: pages 441 to 460
# 🧩 Processing batch: pages 461 to 480
# 🧩 Processing batch: pages 481 to 500
# 🧩 Processing batch: pages 501 to 520
# 🧩 Processing batch: pages 521 to 540
# 🧩 Processing batch: pages 541 to 560
# 🧩 Processing batch: pages 561 to 580
# 🧩 Processing batch: pages 581 to 594
# 🔍 Extracting text from page 1...
# 🔍 Extracting text from page 21...
# 🔍 Extracting text from page 41...
# 🔍 Extracting text from page 61...
# 🔍 Extracting text from page 81...
# 🔍 Extracting text from page 101...
# 🔍 Extracting text from page 121...
# 🔍 Extracting text from page 141...
# 🔍 Extracting text from page 161...
# 🔍 Extracting text from page 181...🔍 Extracting text from page 201...
#
# 🔍 Extracting text from page 221...
# 🔍 Extracting text from page 241...
# 🔍 Extracting text from page 261...
# 🔍 Extracting text from page 281...
# 🔍 Extracting text from page 301...
# ⚠️ No text found on page 21
# 🔍 Extracting text from page 22...
# ⚠️ No text found on page 141
# 🔍 Extracting text from page 142...
# ⚠️ No text found on page 281
# 🔍 Extracting text from page 282...
# ⚠️ No text found on page 241
# 🔍 Extracting text from page 242...
# ⚠️ No text found on page 121
# 🔍 Extracting text from page 122...
# ⚠️ No text found on page 201
# 🔍 Extracting text from page 202...
# ⚠️ No text found on page 101
# 🔍 Extracting text from page 102...
# ⚠️ No text found on page 1
# 🔍 Extracting text from page 2...
# ⚠️ No text found on page 221
# 🔍 Extracting text from page 222...
# ⚠️ No text found on page 22
# 🔍 Extracting text from page 23...
# ⚠️ No text found on page 81
# 🔍 Extracting text from page 82...
# ⚠️ No text found on page 41
# 🔍 Extracting text from page 42...
# ⚠️ No text found on page 122
# 🔍 Extracting text from page 123...
# ✅ Text found on page 61 (2756 characters)
# 🔍 Extracting text from page 62...
# ⚠️ No text found on page 301
# 🔍 Extracting text from page 302...
# ⚠️ No text found on page 261
# 🔍 Extracting text from page 262...
# ⚠️ No text found on page 161
# 🔍 Extracting text from page 162...
# ⚠️ No text found on page 181
# 🔍 Extracting text from page 182...
# ⚠️ No text found on page 102
# 🔍 Extracting text from page 103...
# ⚠️ No text found on page 222
# 🔍 Extracting text from page 223...
# ⚠️ No text found on page 142
# 🔍 Extracting text from page 143...
# ✅ Text found on page 2 (11 characters)
# 🔍 Extracting text from page 3...
# ⚠️ No text found on page 23
# 🔍 Extracting text from page 24...
# ⚠️ No text found on page 262
# 🔍 Extracting text from page 263...
# ⚠️ No text found on page 162
# 🔍 Extracting text from page 163...
# ⚠️ No text found on page 282
# 🔍 Extracting text from page 283...
# ⚠️ No text found on page 82
# 🔍 Extracting text from page 83...
# ⚠️ No text found on page 242
# 🔍 Extracting text from page 243...
# ⚠️ No text found on page 42
# 🔍 Extracting text from page 43...
# ⚠️ No text found on page 3
# 🔍 Extracting text from page 4...
# ⚠️ No text found on page 143
# 🔍 Extracting text from page 144...
# ⚠️ No text found on page 302
# 🔍 Extracting text from page 303...
# ⚠️ No text found on page 202
# 🔍 Extracting text from page 203...
# ⚠️ No text found on page 62
# 🔍 Extracting text from page 63...
# ⚠️ No text found on page 103
# 🔍 Extracting text from page 104...
# ⚠️ No text found on page 24
# 🔍 Extracting text from page 25...
# ⚠️ No text found on page 163
# 🔍 Extracting text from page 164...
# ⚠️ No text found on page 4
# 🔍 Extracting text from page 5...
# ⚠️ No text found on page 223
# 🔍 Extracting text from page 224...
# ⚠️ No text found on page 263
# 🔍 Extracting text from page 264...
# ⚠️ No text found on page 123
# 🔍 Extracting text from page 124...
# ⚠️ No text found on page 283
# 🔍 Extracting text from page 284...
# ⚠️ No text found on page 182
# 🔍 Extracting text from page 183...
# ⚠️ No text found on page 243
# 🔍 Extracting text from page 244...
# ⚠️ No text found on page 124
# 🔍 Extracting text from page 125...
# ⚠️ No text found on page 203
# 🔍 Extracting text from page 204...
# ⚠️ No text found on page 43
# 🔍 Extracting text from page 44...
# ⚠️ No text found on page 5
# 🔍 Extracting text from page 6...
# ⚠️ No text found on page 144
# 🔍 Extracting text from page 145...
# ⚠️ No text found on page 264
# 🔍 Extracting text from page 265...
# ⚠️ No text found on page 164
# 🔍 Extracting text from page 165...
# ⚠️ No text found on page 303
# 🔍 Extracting text from page 304...
# ⚠️ No text found on page 104
# 🔍 Extracting text from page 105...
# ⚠️ No text found on page 25
# 🔍 Extracting text from page 26...
# ⚠️ No text found on page 83
# 🔍 Extracting text from page 84...
# ⚠️ No text found on page 244
# 🔍 Extracting text from page 245...
# ⚠️ No text found on page 284
# 🔍 Extracting text from page 285...
# ⚠️ No text found on page 6
# 🔍 Extracting text from page 7...
# ⚠️ No text found on page 125
# 🔍 Extracting text from page 126...
# ⚠️ No text found on page 183
# 🔍 Extracting text from page 184...
# ⚠️ No text found on page 145
# 🔍 Extracting text from page 146...
# ⚠️ No text found on page 224
# 🔍 Extracting text from page 225...
# ⚠️ No text found on page 44
# 🔍 Extracting text from page 45...
# ⚠️ No text found on page 204
# 🔍 Extracting text from page 205...
# ⚠️ No text found on page 265
# 🔍 Extracting text from page 266...
# ⚠️ No text found on page 26
# 🔍 Extracting text from page 27...
# ⚠️ No text found on page 165
# 🔍 Extracting text from page 166...
# ⚠️ No text found on page 304
# 🔍 Extracting text from page 305...
# ⚠️ No text found on page 126
# 🔍 Extracting text from page 127...
# ⚠️ No text found on page 146
# 🔍 Extracting text from page 147...
# ⚠️ No text found on page 105
# 🔍 Extracting text from page 106...
# ⚠️ No text found on page 63
# 🔍 Extracting text from page 64...
# ⚠️ No text found on page 245
# 🔍 Extracting text from page 246...
# ⚠️ No text found on page 7
# 🔍 Extracting text from page 8...
# ⚠️ No text found on page 205
# 🔍 Extracting text from page 206...
# ⚠️ No text found on page 84
# 🔍 Extracting text from page 85...
# ⚠️ No text found on page 285
# 🔍 Extracting text from page 286...
# ⚠️ No text found on page 64
# 🔍 Extracting text from page 65...
# ⚠️ No text found on page 45
# 🔍 Extracting text from page 46...
# ⚠️ No text found on page 27
# 🔍 Extracting text from page 28...
# ✅ Text found on page 8 (19 characters)
# 🔍 Extracting text from page 9...
# ⚠️ No text found on page 225
# 🔍 Extracting text from page 226...
# ⚠️ No text found on page 266
# 🔍 Extracting text from page 267...
# ⚠️ No text found on page 147
# 🔍 Extracting text from page 148...
# ⚠️ No text found on page 305
# 🔍 Extracting text from page 306...
# ⚠️ No text found on page 106
# 🔍 Extracting text from page 107...
# ⚠️ No text found on page 127
# 🔍 Extracting text from page 128...
# ⚠️ No text found on page 246
# 🔍 Extracting text from page 247...
# ⚠️ No text found on page 206
# 🔍 Extracting text from page 207...
# ⚠️ No text found on page 184
# 🔍 Extracting text from page 185...
# ✅ Text found on page 9 (432 characters)
# 🔍 Extracting text from page 10...
# ⚠️ No text found on page 226
# 🔍 Extracting text from page 227...
# ⚠️ No text found on page 166
# 🔍 Extracting text from page 167...
# ⚠️ No text found on page 85
# 🔍 Extracting text from page 86...
# ⚠️ No text found on page 286
# 🔍 Extracting text from page 287...
# ⚠️ No text found on page 65
# 🔍 Extracting text from page 66...
# ⚠️ No text found on page 247
# 🔍 Extracting text from page 248...
# ⚠️ No text found on page 28
# 🔍 Extracting text from page 29...
# ✅ Text found on page 10 (187 characters)
# 🔍 Extracting text from page 11...
# ⚠️ No text found on page 267
# 🔍 Extracting text from page 268...
# ⚠️ No text found on page 128
# 🔍 Extracting text from page 129...
# ⚠️ No text found on page 185
# 🔍 Extracting text from page 186...
# ⚠️ No text found on page 167
# 🔍 Extracting text from page 168...
# ⚠️ No text found on page 46
# 🔍 Extracting text from page 47...
# ⚠️ No text found on page 148
# 🔍 Extracting text from page 149...
# ⚠️ No text found on page 86
# 🔍 Extracting text from page 87...
# ⚠️ No text found on page 207
# 🔍 Extracting text from page 208...
# ⚠️ No text found on page 227
# 🔍 Extracting text from page 228...
# ⚠️ No text found on page 248
# 🔍 Extracting text from page 249...
# ⚠️ No text found on page 29
# 🔍 Extracting text from page 30...
# ⚠️ No text found on page 306
# 🔍 Extracting text from page 307...
# ⚠️ No text found on page 287
# 🔍 Extracting text from page 288...
# ⚠️ No text found on page 66
# 🔍 Extracting text from page 67...
# ⚠️ No text found on page 129
# 🔍 Extracting text from page 130...
# ⚠️ No text found on page 11
# 🔍 Extracting text from page 12...
# ⚠️ No text found on page 186
# 🔍 Extracting text from page 187...
# ⚠️ No text found on page 87
# 🔍 Extracting text from page 88...
# ⚠️ No text found on page 268
# 🔍 Extracting text from page 269...
# ❌ Error processing page 249: not enough values to unpack (expected 1, got 0)
# 🔍 Extracting text from page 250...
# ⚠️ No text found on page 228
# 🔍 Extracting text from page 229...
# ⚠️ No text found on page 130
# 🔍 Extracting text from page 131...
# ⚠️ No text found on page 208
# 🔍 Extracting text from page 209...
# ⚠️ No text found on page 168
# 🔍 Extracting text from page 169...
# ⚠️ No text found on page 107
# 🔍 Extracting text from page 108...
# ⚠️ No text found on page 187
# 🔍 Extracting text from page 188...
# ⚠️ No text found on page 288
# 🔍 Extracting text from page 289...
# ⚠️ No text found on page 307
# 🔍 Extracting text from page 308...
# ⚠️ No text found on page 30
# 🔍 Extracting text from page 31...
# ⚠️ No text found on page 88
# 🔍 Extracting text from page 89...
# ⚠️ No text found on page 12
# 🔍 Extracting text from page 13...
# ⚠️ No text found on page 229
# 🔍 Extracting text from page 230...
# ⚠️ No text found on page 47
# 🔍 Extracting text from page 48...
# ⚠️ No text found on page 269
# 🔍 Extracting text from page 270...
# ⚠️ No text found on page 149
# 🔍 Extracting text from page 150...
# ⚠️ No text found on page 250
# 🔍 Extracting text from page 251...
# ⚠️ No text found on page 67
# 🔍 Extracting text from page 68...
# ⚠️ No text found on page 13
# 🔍 Extracting text from page 14...
# ⚠️ No text found on page 89
# 🔍 Extracting text from page 90...
# ⚠️ No text found on page 131
# 🔍 Extracting text from page 132...
# ⚠️ No text found on page 289
# 🔍 Extracting text from page 290...
# ⚠️ No text found on page 31
# 🔍 Extracting text from page 32...
# ⚠️ No text found on page 230
# 🔍 Extracting text from page 231...
# ⚠️ No text found on page 108
# 🔍 Extracting text from page 109...
# ⚠️ No text found on page 270
# 🔍 Extracting text from page 271...
# ⚠️ No text found on page 209
# 🔍 Extracting text from page 210...
# ⚠️ No text found on page 188
# 🔍 Extracting text from page 189...
# ⚠️ No text found on page 308
# 🔍 Extracting text from page 309...
# ⚠️ No text found on page 68
# 🔍 Extracting text from page 69...
# ✅ Text found on page 290 (1124 characters)
# 🔍 Extracting text from page 291...
# ⚠️ No text found on page 90
# 🔍 Extracting text from page 91...
# ⚠️ No text found on page 48
# 🔍 Extracting text from page 49...
# ⚠️ No text found on page 251
# 🔍 Extracting text from page 252...
# ⚠️ No text found on page 210
# 🔍 Extracting text from page 211...
# ⚠️ No text found on page 14
# 🔍 Extracting text from page 15...
# ⚠️ No text found on page 231
# 🔍 Extracting text from page 232...
# ⚠️ No text found on page 271
# 🔍 Extracting text from page 272...
# ⚠️ No text found on page 309
# 🔍 Extracting text from page 310...
# ⚠️ No text found on page 32
# 🔍 Extracting text from page 33...
# ⚠️ No text found on page 150
# 🔍 Extracting text from page 151...
# ⚠️ No text found on page 132
# 🔍 Extracting text from page 133...
# ⚠️ No text found on page 252
# 🔍 Extracting text from page 253...
# ⚠️ No text found on page 69
# 🔍 Extracting text from page 70...
# ⚠️ No text found on page 169
# 🔍 Extracting text from page 170...
# ⚠️ No text found on page 33
# 🔍 Extracting text from page 34...
# ⚠️ No text found on page 91
# 🔍 Extracting text from page 92...
# ⚠️ No text found on page 310
# 🔍 Extracting text from page 311...
# ⚠️ No text found on page 211
# 🔍 Extracting text from page 212...
# ⚠️ No text found on page 291
# 🔍 Extracting text from page 292...
# ⚠️ No text found on page 232
# 🔍 Extracting text from page 233...
# ⚠️ No text found on page 109
# 🔍 Extracting text from page 110...
# ⚠️ No text found on page 49
# 🔍 Extracting text from page 50...
# ⚠️ No text found on page 15
# 🔍 Extracting text from page 16...
# ⚠️ No text found on page 272
# 🔍 Extracting text from page 273...
# ⚠️ No text found on page 133
# 🔍 Extracting text from page 134...
# ⚠️ No text found on page 110
# 🔍 Extracting text from page 111...
# ⚠️ No text found on page 292
# 🔍 Extracting text from page 293...
# ⚠️ No text found on page 70
# 🔍 Extracting text from page 71...
# ⚠️ No text found on page 233
# 🔍 Extracting text from page 234...
# ⚠️ No text found on page 189
# 🔍 Extracting text from page 190...
# ⚠️ No text found on page 92
# 🔍 Extracting text from page 93...
# ⚠️ No text found on page 16
# 🔍 Extracting text from page 17...
# ⚠️ No text found on page 253
# 🔍 Extracting text from page 254...
# ⚠️ No text found on page 212
# 🔍 Extracting text from page 213...
# ⚠️ No text found on page 34
# 🔍 Extracting text from page 35...
# ⚠️ No text found on page 50
# 🔍 Extracting text from page 51...
# ⚠️ No text found on page 293
# 🔍 Extracting text from page 294...
# ⚠️ No text found on page 151
# 🔍 Extracting text from page 152...
# ⚠️ No text found on page 311
# 🔍 Extracting text from page 312...
# ⚠️ No text found on page 170
# 🔍 Extracting text from page 171...
# ⚠️ No text found on page 213
# 🔍 Extracting text from page 214...
# ⚠️ No text found on page 71
# 🔍 Extracting text from page 72...
# ⚠️ No text found on page 134
# 🔍 Extracting text from page 135...
# ⚠️ No text found on page 93
# 🔍 Extracting text from page 94...
# ⚠️ No text found on page 51
# 🔍 Extracting text from page 52...
# ⚠️ No text found on page 234
# 🔍 Extracting text from page 235...
# ⚠️ No text found on page 273
# 🔍 Extracting text from page 274...
# ⚠️ No text found on page 254
# 🔍 Extracting text from page 255...
# ⚠️ No text found on page 35
# 🔍 Extracting text from page 36...
# ⚠️ No text found on page 152
# 🔍 Extracting text from page 153...
# ⚠️ No text found on page 135
# 🔍 Extracting text from page 136...
# ⚠️ No text found on page 190
# 🔍 Extracting text from page 191...
# ⚠️ No text found on page 17
# 🔍 Extracting text from page 18...
# ⚠️ No text found on page 312
# 🔍 Extracting text from page 313...
# ⚠️ No text found on page 52
# 🔍 Extracting text from page 53...
# ✅ Text found on page 111 (1495 characters)
# 🔍 Extracting text from page 112...
# ⚠️ No text found on page 171
# 🔍 Extracting text from page 172...
# ⚠️ No text found on page 294
# 🔍 Extracting text from page 295...
# ⚠️ No text found on page 214
# 🔍 Extracting text from page 215...
# ⚠️ No text found on page 94
# 🔍 Extracting text from page 95...
# ✅ Text found on page 255 (7 characters)
# 🔍 Extracting text from page 256...
# ⚠️ No text found on page 36
# 🔍 Extracting text from page 37...
# ⚠️ No text found on page 235
# 🔍 Extracting text from page 236...
# ⚠️ No text found on page 95
# 🔍 Extracting text from page 96...
# ⚠️ No text found on page 274
# 🔍 Extracting text from page 275...
# ⚠️ No text found on page 172
# 🔍 Extracting text from page 173...
# ⚠️ No text found on page 191
# 🔍 Extracting text from page 192...
# ⚠️ No text found on page 72
# 🔍 Extracting text from page 73...
# ⚠️ No text found on page 295
# 🔍 Extracting text from page 296...
# ⚠️ No text found on page 136
# 🔍 Extracting text from page 137...
# ❌ Error processing page 296: Invalid octal b'611' (393)
# 🔍 Extracting text from page 297...
# ❌ Error processing page 236: Invalid octal b'611' (393)
# 🔍 Extracting text from page 237...
# ❌ Error processing page 215: Invalid octal b'611' (393)
# 🔍 Extracting text from page 216...
# ⚠️ No text found on page 96
# 🔍 Extracting text from page 97...
# ⚠️ No text found on page 153
# 🔍 Extracting text from page 154...
# ⚠️ No text found on page 18
# 🔍 Extracting text from page 19...
# ⚠️ No text found on page 313
# 🔍 Extracting text from page 314...
# ⚠️ No text found on page 37
# 🔍 Extracting text from page 38...
# ⚠️ No text found on page 112
# 🔍 Extracting text from page 113...
# ⚠️ No text found on page 173
# 🔍 Extracting text from page 174...
# ⚠️ No text found on page 19
# 🔍 Extracting text from page 20...
# ⚠️ No text found on page 256
# 🔍 Extracting text from page 257...
# ⚠️ No text found on page 97
# 🔍 Extracting text from page 98...
# ⚠️ No text found on page 237
# 🔍 Extracting text from page 238...
# ⚠️ No text found on page 275
# 🔍 Extracting text from page 276...
# ⚠️ No text found on page 53
# 🔍 Extracting text from page 54...
# ⚠️ No text found on page 216
# 🔍 Extracting text from page 217...
# ⚠️ No text found on page 314
# 🔍 Extracting text from page 315...
# ⚠️ No text found on page 73
# 🔍 Extracting text from page 74...
# ⚠️ No text found on page 297
# 🔍 Extracting text from page 298...
# ⚠️ No text found on page 192
# 🔍 Extracting text from page 193...
# ⚠️ No text found on page 238
# 🔍 Extracting text from page 239...
# ⚠️ No text found on page 154
# 🔍 Extracting text from page 155...
# ⚠️ No text found on page 276
# 🔍 Extracting text from page 277...
# ⚠️ No text found on page 174
# 🔍 Extracting text from page 175...
# ⚠️ No text found on page 257
# 🔍 Extracting text from page 258...
# ⚠️ No text found on page 113
# 🔍 Extracting text from page 114...
# ⚠️ No text found on page 20
# 🔍 Extracting text from page 321...
# Data-loss while decompressing corrupted data
# ⚠️ No text found on page 38⚠️ No text found on page 315
# 🔍 Extracting text from page 316...
#
# 🔍 Extracting text from page 39...
# ⚠️ No text found on page 298
# 🔍 Extracting text from page 299...
# ⚠️ No text found on page 193
# 🔍 Extracting text from page 194...
# ⚠️ No text found on page 137
# 🔍 Extracting text from page 138...
# ⚠️ No text found on page 74
# 🔍 Extracting text from page 75...
# ⚠️ No text found on page 239
# 🔍 Extracting text from page 240...
# ⚠️ No text found on page 54
# 🔍 Extracting text from page 55...
# ⚠️ No text found on page 114
# 🔍 Extracting text from page 115...
# ⚠️ No text found on page 155
# 🔍 Extracting text from page 156...
# ⚠️ No text found on page 258
# 🔍 Extracting text from page 259...
# ⚠️ No text found on page 316
# 🔍 Extracting text from page 317...
# ⚠️ No text found on page 217
# 🔍 Extracting text from page 218...
# ⚠️ No text found on page 98
# 🔍 Extracting text from page 99...
# ⚠️ No text found on page 299
# 🔍 Extracting text from page 300...
# ⚠️ No text found on page 75
# 🔍 Extracting text from page 76...
# ⚠️ No text found on page 194
# 🔍 Extracting text from page 195...
# ⚠️ No text found on page 175
# 🔍 Extracting text from page 176...
# ❌ Error processing page 317: not enough values to unpack (expected 1, got 0)
# 🔍 Extracting text from page 318...
# ⚠️ No text found on page 39
# 🔍 Extracting text from page 40...
# ⚠️ No text found on page 277
# 🔍 Extracting text from page 278...
# ⚠️ No text found on page 138
# 🔍 Extracting text from page 139...
# ⚠️ No text found on page 321
# 🔍 Extracting text from page 322...
# ❌ Error processing page 278: Invalid octal b'611' (393)
# 🔍 Extracting text from page 279...
# ⚠️ No text found on page 55
# 🔍 Extracting text from page 56...
# ❌ Error processing page 99: Invalid octal b'611' (393)
# 🔍 Extracting text from page 100...
# ❌ Error processing page 279: Invalid octal b'611' (393)
# 🔍 Extracting text from page 280...
# ❌ Error processing page 300: Invalid octal b'611' (393)
# ❌ Error processing page 195: Invalid octal b'611' (393)
# 🔍 Extracting text from page 196...
# ❌ Error processing page 76: Invalid octal b'611' (393)
# 🔍 Extracting text from page 77...
# 🔍 Extracting text from page 341...
# ❌ Error processing page 218: Invalid octal b'611' (393)
# 🔍 Extracting text from page 219...
# ❌ Error processing page 115: Invalid octal b'611' (393)
# 🔍 Extracting text from page 116...
# ❌ Error processing page 156: Invalid octal b'611' (393)
# 🔍 Extracting text from page 157...
# ❌ Error processing page 240: Invalid octal b'611' (393)
# ❌ Error processing page 56: Invalid octal b'611' (393)
# 🔍 Extracting text from page 57...
# 🔍 Extracting text from page 361...
# ❌ Error processing page 318: Invalid octal b'611' (393)
# 🔍 Extracting text from page 319...
# ⚠️ No text found on page 176
# 🔍 Extracting text from page 177...
# ⚠️ No text found on page 57
# 🔍 Extracting text from page 58...
# ⚠️ No text found on page 322
# 🔍 Extracting text from page 323...
# ⚠️ No text found on page 259
# 🔍 Extracting text from page 260...
# ⚠️ No text found on page 40
# 🔍 Extracting text from page 381...
# ⚠️ No text found on page 280
# 🔍 Extracting text from page 401...
# ⚠️ No text found on page 116
# 🔍 Extracting text from page 117...
# ⚠️ No text found on page 100
# 🔍 Extracting text from page 421...
# ✅ Text found on page 77 (6 characters)
# 🔍 Extracting text from page 78...
# ⚠️ No text found on page 177
# 🔍 Extracting text from page 178...
# ⚠️ No text found on page 341
# 🔍 Extracting text from page 342...
# ⚠️ No text found on page 139
# 🔍 Extracting text from page 140...
# ⚠️ No text found on page 319
# 🔍 Extracting text from page 320...
# ⚠️ No text found on page 157
# 🔍 Extracting text from page 158...
# ⚠️ No text found on page 260
# 🔍 Extracting text from page 441...
# ⚠️ No text found on page 78
# 🔍 Extracting text from page 79...
# ⚠️ No text found on page 117
# 🔍 Extracting text from page 118...
# ✅ Text found on page 178 (2323 characters)
# 🔍 Extracting text from page 179...
# ⚠️ No text found on page 401
# 🔍 Extracting text from page 402...
# ⚠️ No text found on page 361
# 🔍 Extracting text from page 362...
# ⚠️ No text found on page 58
# 🔍 Extracting text from page 59...
# ⚠️ No text found on page 219
# 🔍 Extracting text from page 220...
# ⚠️ No text found on page 323
# 🔍 Extracting text from page 324...
# ⚠️ No text found on page 421
# 🔍 Extracting text from page 422...
# ⚠️ No text found on page 196
# 🔍 Extracting text from page 197...
# ⚠️ No text found on page 381
# 🔍 Extracting text from page 382...
# ⚠️ No text found on page 441
# 🔍 Extracting text from page 442...
# ⚠️ No text found on page 320
# 🔍 Extracting text from page 461...
# ⚠️ No text found on page 158
# 🔍 Extracting text from page 159...
# ⚠️ No text found on page 342
# 🔍 Extracting text from page 343...
# ⚠️ No text found on page 59
# 🔍 Extracting text from page 60...
# ⚠️ No text found on page 402
# 🔍 Extracting text from page 403...
# ⚠️ No text found on page 179
# 🔍 Extracting text from page 180...
# ⚠️ No text found on page 220
# 🔍 Extracting text from page 481...
# ⚠️ No text found on page 79
# 🔍 Extracting text from page 80...
# ⚠️ No text found on page 362
# 🔍 Extracting text from page 363...
# ⚠️ No text found on page 140
# 🔍 Extracting text from page 501...
# ⚠️ No text found on page 382
# 🔍 Extracting text from page 383...
# ⚠️ No text found on page 197
# 🔍 Extracting text from page 198...
# ⚠️ No text found on page 118
# 🔍 Extracting text from page 119...
# ✅ Text found on page 481 (697 characters)
# 🔍 Extracting text from page 482...
# ⚠️ No text found on page 343
# 🔍 Extracting text from page 344...
# ⚠️ No text found on page 180
# 🔍 Extracting text from page 521...
# ⚠️ No text found on page 60
# 🔍 Extracting text from page 541...
# ⚠️ No text found on page 422
# 🔍 Extracting text from page 423...
# ⚠️ No text found on page 363
# 🔍 Extracting text from page 364...
# ⚠️ No text found on page 461
# 🔍 Extracting text from page 462...
# ⚠️ No text found on page 80
# 🔍 Extracting text from page 561...
# ⚠️ No text found on page 442
# 🔍 Extracting text from page 443...
# ⚠️ No text found on page 119
# 🔍 Extracting text from page 120...
# ⚠️ No text found on page 403
# 🔍 Extracting text from page 404...
# ⚠️ No text found on page 324
# 🔍 Extracting text from page 325...
# ⚠️ No text found on page 159
# 🔍 Extracting text from page 160...
# ⚠️ No text found on page 344
# 🔍 Extracting text from page 345...
# ⚠️ No text found on page 443
# 🔍 Extracting text from page 444...
# ⚠️ No text found on page 521
# 🔍 Extracting text from page 522...
# ⚠️ No text found on page 501
# 🔍 Extracting text from page 502...
# ⚠️ No text found on page 423
# 🔍 Extracting text from page 424...
# ⚠️ No text found on page 364
# 🔍 Extracting text from page 365...
# ⚠️ No text found on page 404
# 🔍 Extracting text from page 405...
# ⚠️ No text found on page 383
# 🔍 Extracting text from page 384...
# ⚠️ No text found on page 462
# 🔍 Extracting text from page 463...
# ⚠️ No text found on page 120
# 🔍 Extracting text from page 581...
# ⚠️ No text found on page 482
# 🔍 Extracting text from page 483...
# ⚠️ No text found on page 541
# 🔍 Extracting text from page 542...
# ⚠️ No text found on page 198
# 🔍 Extracting text from page 199...
# ⚠️ No text found on page 160
# ⚠️ No text found on page 384
# 🔍 Extracting text from page 385...
# ⚠️ No text found on page 345
# 🔍 Extracting text from page 346...
# ⚠️ No text found on page 444
# 🔍 Extracting text from page 445...
# ⚠️ No text found on page 561
# 🔍 Extracting text from page 562...
# ⚠️ No text found on page 502
# 🔍 Extracting text from page 503...
# ⚠️ No text found on page 365
# 🔍 Extracting text from page 366...
# ⚠️ No text found on page 424
# 🔍 Extracting text from page 425...
# ⚠️ No text found on page 325
# 🔍 Extracting text from page 326...
# ⚠️ No text found on page 542
# 🔍 Extracting text from page 543...
# ⚠️ No text found on page 522
# 🔍 Extracting text from page 523...
# ⚠️ No text found on page 199
# 🔍 Extracting text from page 200...
# ⚠️ No text found on page 483
# 🔍 Extracting text from page 484...
# ⚠️ No text found on page 463
# 🔍 Extracting text from page 464...
# ⚠️ No text found on page 562
# 🔍 Extracting text from page 563...
# ⚠️ No text found on page 346
# 🔍 Extracting text from page 347...
# ⚠️ No text found on page 425
# 🔍 Extracting text from page 426...
# ⚠️ No text found on page 326
# 🔍 Extracting text from page 327...
# ⚠️ No text found on page 405
# 🔍 Extracting text from page 406...
# Data-loss while decompressing corrupted data
# ⚠️ No text found on page 503
# 🔍 Extracting text from page 504...
# ⚠️ No text found on page 385
# 🔍 Extracting text from page 386...
# ⚠️ No text found on page 543
# 🔍 Extracting text from page 544...
# ⚠️ No text found on page 581
# 🔍 Extracting text from page 582...
# ⚠️ No text found on page 366
# 🔍 Extracting text from page 367...
# ⚠️ No text found on page 464
# 🔍 Extracting text from page 465...
# ⚠️ No text found on page 386
# 🔍 Extracting text from page 387...
# ⚠️ No text found on page 563
# 🔍 Extracting text from page 564...
# ⚠️ No text found on page 523
# 🔍 Extracting text from page 524...
# ⚠️ No text found on page 426
# 🔍 Extracting text from page 427...
# ⚠️ No text found on page 484
# 🔍 Extracting text from page 485...
# ⚠️ No text found on page 544
# 🔍 Extracting text from page 545...
# ⚠️ No text found on page 200
# ⚠️ No text found on page 327
# 🔍 Extracting text from page 328...
# ⚠️ No text found on page 406
# 🔍 Extracting text from page 407...
# ⚠️ No text found on page 445
# 🔍 Extracting text from page 446...
# ⚠️ No text found on page 347
# 🔍 Extracting text from page 348...
# ⚠️ No text found on page 582
# 🔍 Extracting text from page 583...
# ⚠️ No text found on page 564
# 🔍 Extracting text from page 565...
# ⚠️ No text found on page 387
# 🔍 Extracting text from page 388...
# ⚠️ No text found on page 504
# 🔍 Extracting text from page 505...
# ⚠️ No text found on page 465
# 🔍 Extracting text from page 466...
# ⚠️ No text found on page 545
# 🔍 Extracting text from page 546...
# ⚠️ No text found on page 367
# 🔍 Extracting text from page 368...
# ⚠️ No text found on page 427
# 🔍 Extracting text from page 428...
# ⚠️ No text found on page 388
# 🔍 Extracting text from page 389...
# ⚠️ No text found on page 524
# 🔍 Extracting text from page 525...
# ⚠️ No text found on page 485
# 🔍 Extracting text from page 486...
# ❌ Error processing page 328: Invalid octal b'476' (318)
# 🔍 Extracting text from page 329...
# ❌ Error processing page 583: Invalid octal b'476' (318)
# 🔍 Extracting text from page 584...
# ❌ Error processing page 466: Invalid octal b'476' (318)
# 🔍 Extracting text from page 467...
# ❌ Error processing page 428: Invalid octal b'476' (318)
# 🔍 Extracting text from page 429...
# ❌ Error processing page 546: Invalid octal b'476' (318)
# 🔍 Extracting text from page 547...
# ❌ Error processing page 389: Invalid octal b'476' (318)
# 🔍 Extracting text from page 390...
# ❌ Error processing page 565: Invalid octal b'476' (318)
# 🔍 Extracting text from page 566...
# ❌ Error processing page 368: Invalid octal b'476' (318)
# 🔍 Extracting text from page 369...
# ❌ Error processing page 446: Invalid octal b'476' (318)
# 🔍 Extracting text from page 447...
# ⚠️ No text found on page 407
# 🔍 Extracting text from page 408...
# ⚠️ No text found on page 505
# 🔍 Extracting text from page 506...
# ⚠️ No text found on page 348
# 🔍 Extracting text from page 349...
# ⚠️ No text found on page 408
# 🔍 Extracting text from page 409...
# ✅ Text found on page 447 (1399 characters)
# 🔍 Extracting text from page 448...
# ⚠️ No text found on page 369
# 🔍 Extracting text from page 370...
# ⚠️ No text found on page 329
# 🔍 Extracting text from page 330...
# Data-loss while decompressing corrupted data
# ✅ Text found on page 429 (2748 characters)
# 🔍 Extracting text from page 430...
# ⚠️ No text found on page 584
# 🔍 Extracting text from page 585...
# ⚠️ No text found on page 547
# 🔍 Extracting text from page 548...
# ⚠️ No text found on page 566
# 🔍 Extracting text from page 567...
# ⚠️ No text found on page 349
# 🔍 Extracting text from page 350...
# ⚠️ No text found on page 390
# 🔍 Extracting text from page 391...
# ⚠️ No text found on page 409
# 🔍 Extracting text from page 410...
# ⚠️ No text found on page 486
# 🔍 Extracting text from page 487...
# ⚠️ No text found on page 467
# 🔍 Extracting text from page 468...
# ⚠️ No text found on page 506
# 🔍 Extracting text from page 507...
# ⚠️ No text found on page 330
# 🔍 Extracting text from page 331...
# ⚠️ No text found on page 448
# 🔍 Extracting text from page 449...
# ⚠️ No text found on page 430
# 🔍 Extracting text from page 431...
# ⚠️ No text found on page 525
# 🔍 Extracting text from page 526...
# ⚠️ No text found on page 391
# 🔍 Extracting text from page 392...
# ⚠️ No text found on page 567
# 🔍 Extracting text from page 568...
# ⚠️ No text found on page 410
# 🔍 Extracting text from page 411...
# ⚠️ No text found on page 468
# 🔍 Extracting text from page 469...
# ⚠️ No text found on page 585
# 🔍 Extracting text from page 586...
# ⚠️ No text found on page 350
# 🔍 Extracting text from page 351...
# ⚠️ No text found on page 548
# 🔍 Extracting text from page 549...
# ⚠️ No text found on page 370
# 🔍 Extracting text from page 371...
# ⚠️ No text found on page 431
# 🔍 Extracting text from page 432...
# ⚠️ No text found on page 392
# 🔍 Extracting text from page 393...
# ❌ Error processing page 449: not enough values to unpack (expected 1, got 0)
# 🔍 Extracting text from page 450...
# ⚠️ No text found on page 526
# 🔍 Extracting text from page 527...
# ⚠️ No text found on page 507
# 🔍 Extracting text from page 508...
# ⚠️ No text found on page 331
# 🔍 Extracting text from page 332...
# ⚠️ No text found on page 586
# 🔍 Extracting text from page 587...
# ⚠️ No text found on page 469
# 🔍 Extracting text from page 470...
# ⚠️ No text found on page 351
# 🔍 Extracting text from page 352...
# ⚠️ No text found on page 549
# 🔍 Extracting text from page 550...
# ⚠️ No text found on page 568
# 🔍 Extracting text from page 569...
# ⚠️ No text found on page 411
# 🔍 Extracting text from page 412...
# ⚠️ No text found on page 487
# 🔍 Extracting text from page 488...
# ⚠️ No text found on page 432
# 🔍 Extracting text from page 433...
# ⚠️ No text found on page 332
# 🔍 Extracting text from page 333...
# ⚠️ No text found on page 393
# 🔍 Extracting text from page 394...
# ⚠️ No text found on page 569
# 🔍 Extracting text from page 570...
# ⚠️ No text found on page 352
# 🔍 Extracting text from page 353...
# ⚠️ No text found on page 470
# 🔍 Extracting text from page 471...
# ⚠️ No text found on page 450
# 🔍 Extracting text from page 451...
# ⚠️ No text found on page 371
# 🔍 Extracting text from page 372...
# ⚠️ No text found on page 527
# 🔍 Extracting text from page 528...
# ⚠️ No text found on page 412
# 🔍 Extracting text from page 413...
# ⚠️ No text found on page 433
# 🔍 Extracting text from page 434...
# ⚠️ No text found on page 508
# 🔍 Extracting text from page 509...
# ⚠️ No text found on page 488
# 🔍 Extracting text from page 489...
# ⚠️ No text found on page 394
# 🔍 Extracting text from page 395...
# ⚠️ No text found on page 587
# 🔍 Extracting text from page 588...
# ⚠️ No text found on page 471
# 🔍 Extracting text from page 472...
# ⚠️ No text found on page 570
# 🔍 Extracting text from page 571...
# ⚠️ No text found on page 588
# 🔍 Extracting text from page 589...
# ⚠️ No text found on page 528
# 🔍 Extracting text from page 529...
# ⚠️ No text found on page 333
# 🔍 Extracting text from page 334...
# ⚠️ No text found on page 550
# 🔍 Extracting text from page 551...
# ⚠️ No text found on page 353
# 🔍 Extracting text from page 354...
# ⚠️ No text found on page 372
# 🔍 Extracting text from page 373...
# ⚠️ No text found on page 509
# 🔍 Extracting text from page 510...
# ⚠️ No text found on page 395
# 🔍 Extracting text from page 396...
# ⚠️ No text found on page 489
# 🔍 Extracting text from page 490...
# ⚠️ No text found on page 451
# 🔍 Extracting text from page 452...
# ⚠️ No text found on page 589
# 🔍 Extracting text from page 590...
# ⚠️ No text found on page 434
# 🔍 Extracting text from page 435...
# ⚠️ No text found on page 413
# 🔍 Extracting text from page 414...
# ⚠️ No text found on page 472✅ Text found on page 529 (1600 characters)
# 🔍 Extracting text from page 530...
#
# 🔍 Extracting text from page 473...
# ⚠️ No text found on page 373
# 🔍 Extracting text from page 374...
# ⚠️ No text found on page 354
# 🔍 Extracting text from page 355...
# ⚠️ No text found on page 510
# 🔍 Extracting text from page 511...
# ⚠️ No text found on page 452
# 🔍 Extracting text from page 453...
# ⚠️ No text found on page 396
# 🔍 Extracting text from page 397...
# ⚠️ No text found on page 490
# 🔍 Extracting text from page 491...
# ⚠️ No text found on page 571
# 🔍 Extracting text from page 572...
# ⚠️ No text found on page 334
# 🔍 Extracting text from page 335...
# ⚠️ No text found on page 551
# 🔍 Extracting text from page 552...
# ⚠️ No text found on page 590
# 🔍 Extracting text from page 591...
# ⚠️ No text found on page 355
# 🔍 Extracting text from page 356...
# ⚠️ No text found on page 530
# 🔍 Extracting text from page 531...
# ⚠️ No text found on page 397
# 🔍 Extracting text from page 398...
# ⚠️ No text found on page 453
# 🔍 Extracting text from page 454...
# ⚠️ No text found on page 374
# 🔍 Extracting text from page 375...
# ⚠️ No text found on page 511
# 🔍 Extracting text from page 512...
# ⚠️ No text found on page 572
# 🔍 Extracting text from page 573...
# ⚠️ No text found on page 473
# 🔍 Extracting text from page 474...
# ⚠️ No text found on page 414
# 🔍 Extracting text from page 415...
# ⚠️ No text found on page 335
# 🔍 Extracting text from page 336...
# ⚠️ No text found on page 552
# 🔍 Extracting text from page 553...
# ⚠️ No text found on page 435
# 🔍 Extracting text from page 436...
# ⚠️ No text found on page 356
# 🔍 Extracting text from page 357...
# ⚠️ No text found on page 454
# 🔍 Extracting text from page 455...
# ⚠️ No text found on page 573
# 🔍 Extracting text from page 574...
# ⚠️ No text found on page 415
# 🔍 Extracting text from page 416...
# ⚠️ No text found on page 491
# 🔍 Extracting text from page 492...
# ⚠️ No text found on page 553
# 🔍 Extracting text from page 554...
# ⚠️ No text found on page 591
# 🔍 Extracting text from page 592...
# ✅ Text found on page 436 (1430 characters)
# 🔍 Extracting text from page 437...
# ⚠️ No text found on page 398
# 🔍 Extracting text from page 399...
# ⚠️ No text found on page 512
# 🔍 Extracting text from page 513...
# ⚠️ No text found on page 474
# 🔍 Extracting text from page 475...
# ⚠️ No text found on page 531
# 🔍 Extracting text from page 532...
# ❌ Error processing page 357: Invalid octal b'560' (368)
# 🔍 Extracting text from page 358...
# ❌ Error processing page 574: Invalid octal b'560' (368)
# 🔍 Extracting text from page 575...
# ❌ Error processing page 455: Invalid octal b'560' (368)
# 🔍 Extracting text from page 456...
# ❌ Error processing page 513: Invalid octal b'560' (368)
# 🔍 Extracting text from page 514...
# ❌ Error processing page 475: Invalid octal b'560' (368)
# 🔍 Extracting text from page 476...
# ❌ Error processing page 416: Invalid octal b'560' (368)
# 🔍 Extracting text from page 417...
# ❌ Error processing page 592: Invalid octal b'560' (368)
# 🔍 Extracting text from page 593...
# ❌ Error processing page 437: Invalid octal b'560' (368)
# 🔍 Extracting text from page 438...
# ❌ Error processing page 336: Invalid octal b'560' (368)
# 🔍 Extracting text from page 337...
# ❌ Error processing page 399: Invalid octal b'560' (368)
# 🔍 Extracting text from page 400...
# ⚠️ No text found on page 375
# 🔍 Extracting text from page 376...
# ⚠️ No text found on page 438
# 🔍 Extracting text from page 439...
# ⚠️ No text found on page 358
# 🔍 Extracting text from page 359...
# ⚠️ No text found on page 554
# 🔍 Extracting text from page 555...
# ⚠️ No text found on page 376
# 🔍 Extracting text from page 377...
# ⚠️ No text found on page 575
# 🔍 Extracting text from page 576...
# ⚠️ No text found on page 492
# 🔍 Extracting text from page 493...
# ⚠️ No text found on page 476
# 🔍 Extracting text from page 477...
# ⚠️ No text found on page 532
# 🔍 Extracting text from page 533...
# ⚠️ No text found on page 337
# 🔍 Extracting text from page 338...
# ⚠️ No text found on page 456
# 🔍 Extracting text from page 457...
# ⚠️ No text found on page 417
# 🔍 Extracting text from page 418...
# ⚠️ No text found on page 593
# 🔍 Extracting text from page 594...
# ⚠️ No text found on page 514
# 🔍 Extracting text from page 515...
# ⚠️ No text found on page 439
# 🔍 Extracting text from page 440...
# ✅ Text found on page 576 (1496 characters)
# 🔍 Extracting text from page 577...
# ⚠️ No text found on page 359
# 🔍 Extracting text from page 360...
# ⚠️ No text found on page 493
# 🔍 Extracting text from page 494...
# ⚠️ No text found on page 555
# 🔍 Extracting text from page 556...
# ⚠️ No text found on page 377
# 🔍 Extracting text from page 378...
# ⚠️ No text found on page 477
# 🔍 Extracting text from page 478...
# ⚠️ No text found on page 457
# 🔍 Extracting text from page 458...
# ⚠️ No text found on page 515
# 🔍 Extracting text from page 516...
# ⚠️ No text found on page 533
# 🔍 Extracting text from page 534...
# ⚠️ No text found on page 400
# ⚠️ No text found on page 440
# ⚠️ No text found on page 594
# ⚠️ No text found on page 494
# 🔍 Extracting text from page 495...
# ⚠️ No text found on page 418
# 🔍 Extracting text from page 419...
# ⚠️ No text found on page 577
# 🔍 Extracting text from page 578...
# ⚠️ No text found on page 556
# 🔍 Extracting text from page 557...
# ⚠️ No text found on page 458
# 🔍 Extracting text from page 459...
# ⚠️ No text found on page 360
# ⚠️ No text found on page 338
# 🔍 Extracting text from page 339...
# ⚠️ No text found on page 534
# 🔍 Extracting text from page 535...
# ⚠️ No text found on page 378
# 🔍 Extracting text from page 379...
# ⚠️ No text found on page 516
# 🔍 Extracting text from page 517...
# ⚠️ No text found on page 459
# 🔍 Extracting text from page 460...
# ⚠️ No text found on page 478
# 🔍 Extracting text from page 479...
# ⚠️ No text found on page 578
# 🔍 Extracting text from page 579...
# ⚠️ No text found on page 495
# 🔍 Extracting text from page 496...
# ✅ Text found on page 557 (3146 characters)
# 🔍 Extracting text from page 558...
# ⚠️ No text found on page 517
# 🔍 Extracting text from page 518...
# ⚠️ No text found on page 535
# 🔍 Extracting text from page 536...
# ⚠️ No text found on page 379
# 🔍 Extracting text from page 380...
# ⚠️ No text found on page 419
# 🔍 Extracting text from page 420...
# ⚠️ No text found on page 339
# 🔍 Extracting text from page 340...
# ⚠️ No text found on page 460
# ⚠️ No text found on page 496
# 🔍 Extracting text from page 497...
# ⚠️ No text found on page 558
# 🔍 Extracting text from page 559...
# ⚠️ No text found on page 579
# 🔍 Extracting text from page 580...
# ⚠️ No text found on page 420
# ⚠️ No text found on page 479
# 🔍 Extracting text from page 480...
# ⚠️ No text found on page 536
# 🔍 Extracting text from page 537...
# ⚠️ No text found on page 380
# ⚠️ No text found on page 340
# ⚠️ No text found on page 497
# 🔍 Extracting text from page 498...
# ⚠️ No text found on page 559
# 🔍 Extracting text from page 560...
# ⚠️ No text found on page 518
# 🔍 Extracting text from page 519...
# ⚠️ No text found on page 480
# ⚠️ No text found on page 580
# ⚠️ No text found on page 498
# 🔍 Extracting text from page 499...
# ⚠️ No text found on page 560
# ✅ Text found on page 519 (1536 characters)
# 🔍 Extracting text from page 520...
# ⚠️ No text found on page 537
# 🔍 Extracting text from page 538...
# ⚠️ No text found on page 499
# 🔍 Extracting text from page 500...
# ⚠️ No text found on page 520
# ⚠️ No text found on page 538
# 🔍 Extracting text from page 539...
# ⚠️ No text found on page 500
# ⚠️ No text found on page 539
# 🔍 Extracting text from page 540...
# ✅ Text found on page 540 (3119 characters)
# ✅ All batch tasks completed.
# 📚 Total extracted text length: 25579 characters
# 💾 Extracted text saved to 'extracted_text.txt'
# 📄 Extracted 13 chunks from PDF using pdfplumber
# 🔍 First chunk preview (100 chars): "MATH.-STAT.\nSIM ISAAC MIBWf OM«\nNEWTON'S PRINCIPIA.\nTHE\nMATHEMATICAL PRINCIPLES\nOF\nNATURAL PHILOSOPH"
# 🧾 Previewing extracted chunks:
#
# --- Chunk 1 (length: 652 chars) ---
# MATH.-STAT.
# SIM ISAAC MIBWf OM«
# NEWTON'S PRINCIPIA.
# THE
# MATHEMATICAL PRINCIPLES
# OF
# NATURAL PHILOSOPHY,
# BY SIR ISAAC NEWTON;
# TRANSLATED INTO ENGLISH BY ANDREW MOTTE.
# TO WHICH IS ADDKTV
# NEWTON'S SYSTEM OF THE WORLD ;
# With a P ortrait taken from the Bust in t he Royal O bservatory at G reenwich.
# FIRST
#
# --- Chunk 2 (length: 2763 chars) ---
# 236 THE MATHEMATICAL PRINCIPLES [BOOK 1.
# contents u.ider A X AZ, and B X BZ. Join AB, and let it be cut in G,
# so that AG may be to BG as the particle B to the particle A : and G
# will be the common centre of gravity of the particles A and B. The force
# A X AZ will (by Cor. 2, of the Laws) be resolved
#
# --- Chunk 3 (length: 1495 chars) ---
# SEC. X.I OF NATURAL PHILOSOPHY. 185
# s
# H
# mean time the curvilinear path AP. Let AP be the whole curvilinear
# path described since the wheel touched the globe in A, and the length cf
# this path AP will be to twice the versed sine of the arc |PB as 20 E to
# CB. For let the right line CE (produced if need
# ✅ Test complete.
